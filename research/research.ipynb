# %%
import yaml

yaml_file_path="test.yaml"

with open(yaml_file_path,'r') as yaml_file:
    data=yaml.safe_load(yaml_file)
    
print(data)
# Out:
# {'name': 'Prajwol', 'age': 24, 'skills': ['python', 'machine learning', 'deep learning']}

# %%
data['skills']
# Out:
# ['python', 'machine learning', 'deep learning']
